# %% [markdown]
# ## Exercice 4b
# ## Gérer les données manquantes et filtrer par date
# Les données manquantes sont un problème épineux en analyse de données. Pandas offre plusieurs outils pour les gérer.
#
# ### Consigne
# Le fichier `Data/title_brief.csv` contient les titres de l'IZ HPH (Sandbox Alma SLSP).
#
# * Déterminer le nombre de notices créées par les HEP BEJUNE en 2021

# %%
# Importer les bibliothèques requises
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Chargement des données
df = pd.read_csv('Data/titles_brief.csv')

# %%
df.columns
# Out:
# Index(['MMS Id', 'Original Cataloging Agency', 'Creation Date (Calendar)',
#        'Title'],
#       dtype='object')

# %% [markdown]
# ### Filtrer en fonction de l'année

# %%
df['Creation Date (Calendar)']

# => Actuellement sous forme de chaîne de caractère
# Out:
# 0          2020-11-19
# 1          2020-11-19
# 2          2020-11-19
# 3          2020-11-19
# 4          2020-11-19
#               ...
# 2078152    2022-02-23
# 2078153    2022-02-22
# 2078154    2022-02-22
# 2078155    2022-02-22
# 2078156    2022-02-24
# Name: Creation Date (Calendar), Length: 2078157, dtype: object

# %%
# Filtrer par année de création => ne retenir que les notices de 2021
df['Creation Date (Calendar)'] = pd.to_datetime(df['Creation Date (Calendar)'])
df['Creation Date (Calendar)']
# Out:
# 0         2020-11-19
# 1         2020-11-19
# 2         2020-11-19
# 3         2020-11-19
# 4         2020-11-19
#              ...
# 2078152   2022-02-23
# 2078153   2022-02-22
# 2078154   2022-02-22
# 2078155   2022-02-22
# 2078156   2022-02-24
# Name: Creation Date (Calendar), Length: 2078157, dtype: datetime64[ns]

# %%
d_2021 = df.loc[df['Creation Date (Calendar)'].dt.year==2021].copy()
d_2021
# Out:
#                      MMS Id Original Cataloging Agency  \
# 553266   991001397168805520                        NaN
# 553267   991001397168905520                        NaN
# 553268   991001397169005520                        NaN
# 553269   991001397169105520                        NaN
# 553270   991001397169205520                        NaN
# ...                     ...                        ...
# 2077964  991001613119405520                        NaN
# 2077965  991001613119505520                        NaN
# 2077985  991001613121505520                        NaN
# 2077986  991001613121605520                        NaN
# 2078013  991001613343905520                     MiAaPQ
#
#         Creation Date (Calendar)  \
# 553266                2021-01-07
# 553267                2021-01-05
# 553268                2021-01-03
# 553269                2021-01-03
# 553270                2021-01-01
# ...                          ...
# 2077964               2021-10-23
# 2077965               2021-04-21
# 2077985               2021-03-13
# 2077986               2021-03-13
# 2078013               2021-05-27
#
#                                                      Title
# 553266   A Vygotskian Developmental Approach to Second ...
# 553267   Teachers' personal epistemologies : evolving m...
# 553268   Die Moderation strategischer Initiativen Strat...
# 553269   Strategie-Workshop : in fünf Schritten zur er...
# 553270           Bewegungslehre und Biomechanik des Sports
# ...                                                    ...
# 2077964                             ACS bio & med chem au.
# 2077965            Sportivnaia meditsina: nauka i praktika
# 2077985                         Faṣlnāmah-i dawlatʹpizhūhī
# 2077986           Andalas journal of international studies
# 2078013         The Routledge Handbook of Chinese Studies.
#
# [143387 rows x 4 columns]

# %% [markdown]
# ### Filtrer par "agence de catalogage"

# %%
# Afficher en tant que liste permet de voir toutes les occurrences
list(d_2021['Original Cataloging Agency'].unique())
# Out:
# [nan,
#  'RERO vdches',
#  'CH-ZuSLS HPH FR',
#  'RERO jubmdj',
#  'RNV vdroll',
#  'SzBzSBTc BZBC',
#  'GWDNB',
#  'SzZuIDS LU',
#  'CH-ZuSLS HPH IUFFP',
#  'SzZuIDS NEBIS SUPSI-DFA',
#  '1145',
#  'RERO frvhep',
#  'ICCU',
#  'CH-ZuSLS HPH PHSG',
#  'RNV vdbcul',
#  'SzZuIDS NEBIS FHNW-PH-S',
#  'FGM',
#  'MiAaPQ',
#  'CaPaEBR',
#  'CH-ZuSLS BCUFR',
#  'CH ZuSLSP HPH PHSG',
#  'Sz',
#  'CH-ZuSLSP HPH PHSG',
#  'HPH PHSG',
#  'RNV vdnyon',
#  'RNV vdaigl',
#  'RERO vsbcvs',
#  'CHVBK',
#  'DE-101',
#  'SzZuIDS BS/BE B400',
#  'SzZuIDS BS/BE B511',
#  'SzZuIDS BS/BE A342',
#  'DLC',
#  'RERO geies-',
#  'ZWZ',
#  'NLC',
#  'SzZuIDS NEBIS ZBZ',
#  'RNV vdjoux',
#  'ABES',
#  'CHZuSLSP HPH PHSG',
#  'RERO vsbcvm',
#  'RNV vdorbe',
#  'FR-751131015',
#  'RNV vdpuid',
#  'NLE',
#  'RNV vdcris',
#  'RNV vdaven',
#  'RNV vdchsu',
#  'RERO geufpe',
#  'RERO frbcuc',
#  'RERO geucds',
#  'RNV lahetsl',
#  'RERO neirdp',
#  'RERO vsheso',
#  'RERO vshevs',
#  'RNV vdidmo',
#  'RNV vdbstl',
#  'RERO laiuhm',
#  'SzZuIDS NEBIS',
#  'RERO nebpun',
#  'RNV vdlufe',
#  'RERO vsbcce',
#  '1245',
#  'DEBBG',
#  'SzZuIDS NEBIS UZH',
#  'RNV vdxxxx',
#  'RERO geucmu',
#  'RNV vdptlz',
#  'CH-ZuSLS UNIGE',
#  'CH-ZuSLS ZPH HFH',
#  'RNV vdpran',
#  'RNV vdbex',
#  'DE-B1597',
#  'FINmELB',
#  'NO-TrBIB',
#  'UkMaJRU',
#  'Waxmann',
#  'Verlag Barbara Budrich',
#  'MdBmJHUP',
#  'ScCtBLL',
#  'CHZu-SLS HPH PHSG',
#  'RNV',
#  'CHBCC',
#  'RNV vdgla-',
#  'RERO',
#  'RNV vdecfr',
#  '1180',
#  'CH-ZuSLS HPH BJN',
#  'SzZuIDS BS/BE B500',
#  'DE-627',
#  'RNV vdsarr',
#  'RERO vdren-',
#  'SzZuSLS HPH PHSG',
#  'RNV vdnyco',
#  'SzZuIDS LU LUPHL',
#  'SzZuIDS NEBIS HFH',
#  'SzZuIDS NEBIS FHNW-CMU',
#  'SzZuIDS BS/BE',
#  'EBLCP',
#  'CaBNvSL',
#  'LBSOR/DLC',
#  'CH-ZuSLS RZH E19',
#  'RERO frbbul',
#  'RNV vdcopp',
#  'RNV vdesep',
#  'RNV vdetoy',
#  'zZuIDS NEBIS PHZH',
#  'SzZuIDS NEBIS PHZH',
#  'RERO necfbj',
#  'YDX',
#  'CH ZuSLS HPH PHSG',
#  'CH-ZuSLS RZS',
#  'RERO vdbstl',
#  'CH-ZuSLS ZPH PHZH',
#  'DDB',
#  'DE-604',
#  'GBVCP',
#  'RNV vdren-',
#  'SzZuIDS PHSG',
#  'SzZuIDS BS/BE B517',
#  'ZBZ',
#  'RERO vdcoss',
#  'RNV vdvall',
#  'RERO vdbuss',
#  'RERO njhep-',
#  'RNV vdfroi',
#  'SzBzSBTc LUBUL',
#  'SzZuIDS BS/BE A150',
#  'RNV vdpran-',
#  'CH-ZuSLS HPH-PHSG',
#  'RERO gevbpu',
#  '1280',
#  'CH-ZuSLS UBS A332',
#  'CH-ZuSLS UBS A342',
#  'SzZuIDS BS/BE B437',
#  'HEBIS',
#  'CH-ZuSLS UBE B452',
#  'SzZuIDS NEBIS BFH-HAFL',
#  'RNV vdgla',
#  'RNV vdhep-',
#  'CH-ZuSLS UBE B517',
#  'CH-ZuSLS ZBS',
#  'RNV vdberc',
#  'SzZuIDS NEBIS PHGR',
#  'CH-ZuSLS  HPH PHSG',
#  'SzZuIDS LU LUPHS',
#  'RNV vdtsap',
#  'RERO labcur',
#  'SzZuIDS NEBIS FHNW-PH-L',
#  'SzZuIDS NEBIS BFH-SA',
#  'CH-ZuSLS UBE',
#  'SzZuIDS NEBIS UZH-SLZ',
#  'H-ZuSLS HPH PHSG',
#  'RERO nebpup',
#  'CH-ZuSLS UZB ZB',
#  'RERO nearcn',
#  'StDuBDS',
#  'CH_ZuSLS TRI tfla',
#  'Abes',
#  'RERO vdbcul',
#  'RERO laciob',
#  'DEBSZ',
#  'CH-ZuSLS HESSO hetsge',
#  'RERO necfbv',
#  'RNV vdjora',
#  'BDF',
#  'CH-ZuSLS',
#  'CH-ZuSLS HESSO EIARC-NE',
#  'RNV vdbegn',
#  'RNV vdveve',
#  'RNV vdgeno',
#  'SzZuIDS NEBIS ETH-BIB',
#  'RERO neubfl',
#  'SzZUIDS',
#  'RNV vdbeau',
#  'RNV vdsala',
#  'RERO labcud',
#  'SzZuIDS NEBIS UZH-HBZ-N',
#  '1200',
#  'CH-ZuSLS UBS A296',
#  'RERO juecg-',
#  'RERO jubmda',
#  'CH-ZuSLS UZB UROSE',
#  'SzZuIDS NEBIS ZHDK-MIZ',
#  'RNV vdcovv',
#  'RNV vdecha',
#  'CH-ZuSLS HPH EHB',
#  'RERO vsvadi',
#  'SzZuIDS NEBIS FHNW-AG',
#  'SzZuIDS NEBIS UZH-BFB',
#  'RERO neueth',
#  'RERO geulhg',
#  'CH-ZuSLS RZH N12',
#  'SzZuIDS NEBIS UZH-IFE',
#  'RNV vdcoss',
#  'RERO vdetoy',
#  'CH-ZuSLSHPH PHSG',
#  'SzZuIDS NEBIS FHNW-AGI',
#  'CH-ZuSLS ZHK',
#  'RERO vdtour',
#  'CH-ZuSLS BFH E71',
#  'CH-ZuSLS HESSO vsheso',
#  'CH-ZuSLS BFH B437',
#  'CH-ZuSLS HESSO headge',
#  'SzZuIDS NEBIS UPHZH',
#  'FRBML',
#  'CN5O4',
#  'CH-ZuSLS UBS',
#  'CH-ZuSLS SUPSI',
#  'UKMGB',
#  'NL-LeKB',
#  'SzZuIDS BS/BE B515',
#  'RERO neuses',
#  'SzZuIDS UZH',
#  'SzZuIDS NEBIS FHNW PH BsLi',
#  'SzZuIDS BS/BE B460',
#  'SzZuIDS LU LUHGK',
#  'SzZuIDS BS/BE A334',
#  'CH-ZuSLS HPH  PHSG',
#  'RERO neusfm',
#  'PHZH UPBEA',
#  'CH-ZuSLS FHNW E39',
#  'SzZuIDS BS/BE B450',
#  'RERO neubc-',
#  'SzZuIDS NEBIS FHNW-BIB',
#  'RERO frvvcr',
#  'RERO jucold',
#  'RNV vdhesa',
#  'ETH-BIB',
#  'RNV vdflor',
#  'CH-ZuSLS FHNW E44',
#  'SzZuIDS HSG',
#  'CH-ZuSLS ZHDK',
#  'DE-603',
#  'CH-ZuSLS FHNW E60',
#  'CH-ZuSLS ISR irdp',
#  'RERO frvsbc',
#  'UkCbUP',
#  'CH-ZuSLS UBS A238',
#  'Wochenschau Verlag',
#  'NjRocCCS',
#  'TYFRS',
#  'PQKB',
#  'NyNyMAR',
#  'Verlag Julius Klinkhardt',
#  'Budrich Academic Press',
#  'Brill | Schöningh',
#  'S2H',
#  'SzZuIDS NEBIS HES-HEVS-T',
#  'RERO gevbge',
#  'OHX',
#  'RERO neupam',
#  'RNV vdelys',
#  'RNV Orbe',
#  'CH-ZuSLS ETH',
#  'CH-ZuSLS UZB UIFE',
#  'AT-UBW',
#  'CH-ZuSLS HESSO hedsch',
#  'GyFmDB',
#  'N$T',
#  'SzZuIDS BS/BE A125',
#  'RERO vsbcvb',
#  'SzZuIDS BS/BE A330',
#  'SOZARCH',
#  'SzZuIDS BS/BE B410',
#  'SzZuIDS BS/BE A100',
#  'RERO neuthe',
#  'SzZuIDS BS/BE B571',
#  'SzZuIDS BS/BE A166',
#  'RERO neubfd',
#  'SzZuIDS BS/BE B418',
#  'SzZuIDS BS/BE A258',
#  'RERO iftaf-',
#  'NLGGC',
#  'SzZuIDS NEBIS ETH-GTA',
#  'SzZuIDS NEBIS FHNW-TW',
#  'SzZuIDS FHS',
#  'SzZuIDS NEBIS ZHAW-L',
#  'SzZuIDS BS/BE A110',
#  'SzZuIDS LU LUZHB',
#  'SzZuIDS BS/BE B478',
#  'GyFmHBV',
#  'SzZuIDS LU LUHSA',
#  'SzZuIDS BS/BE B440',
#  'RERO gehei-',
#  'SLB',
#  'SzZuIDS NEBIS SNB-ZH',
#  'SzZuIDS BS/BE B593',
#  'SzZuIDS BS/BE B563',
#  'SzBzSBTc tibcfg',
#  'SzZuIDS BS/BE A331',
#  'RERO iftfla',
#  'SzZuIDS BS/BE B451',
#  'SzZuIDS BS/BE A296',
#  'IDS NEBIS ZBZ',
#  'IDS NEBIS SUPSI',
#  'IDS NEBIS FH-HSWZFH',
#  'IDS BS/BE B460',
#  'Dobis/Libis UZH',
#  'SzZuIDS BS/BE B424',
#  'SzZuIDS BS/BE B429',
#  'SzZuIDS NEBIS FH-HSWZFH',
#  'SzZuIDS BS/BE A210',
#  'SzZuIDS BS/BE A351',
#  'HFS-SO',
#  'SzZuIDS NEBIS LIB4RI EMPA-SG',
#  'SzZuIDS BS/BE B470',
#  'RERO geubfd',
#  'SzZuIDS BS/BE B465',
#  'IDS BS/BE B400',
#  'SzZuIDS BS/BE B581',
#  'IDS BS/BE A100',
#  'EAWAG',
#  'SzZuIDS BS/BE A284',
#  'SzZuIDS BS/BE B430',
#  '0018',
#  'RERO gecesd',
#  'SzZuIDS NEBIS FH-FHA-SA',
#  'SzZuIDS BS/BE A298',
#  'SzZuIDS NEBIS MUG',
#  'SzZuIDS BS/BE A140',
#  'SzZuIDS BS/BE B434',
#  'ETH-WIF',
#  'SzZuIDS BS/BE B425',
#  'RERO geuieg',
#  'SGBN SGLSR',
#  'SzZuIDS BS/BE B445',
#  'NTB',
#  'SzZuIDS BS/BE A348',
#  'RERO vshevv',
#  'SzZuIDS BS/BE A344',
#  'SzZuIDS BS/BE B467',
#  'RERO geulit',
#  'IDS BS/BE',
#  'RERO geudbu',
#  'PHSG',
#  'SzZuIDS BS/BE A202',
#  'SzZuIDS BS/BE A198',
#  'IDS NEBIS ETH-TMA',
#  'SJI',
#  'SzZuIDS BS/BE A360',
#  'HSG',
#  'SzZuIDS NEBIS ETH-WIF',
#  'SzBzSBTc LUBSF',
#  'SzZuIDS NEBIS FH-HGK',
#  'SGBN',
#  'SzZuIDS BS/BE A248',
#  'RERO gevbaa',
#  'SzZuIDS BS/BE B473',
#  'SzZuIDS BS/BE A208',
#  'SzZuIDS BS/BE A370',
#  'NYP',
#  'SzZuIDS BS/BE B490',
#  'SzZuIDS BS/BE B579',
#  'SzZuIDS NEBIS ZHAW-G',
#  'SzZuIDS BS/BE A190',
#  'SzZuIDS BS/BE B420',
#  'SzZuIDS NEBIS HES-EIG',
#  'SzZuIDS NEBIS SOZARCH',
#  'SzZuIDS BS/BE B433',
#  'SzZuIDS NEBIS ETH-BAU',
#  'IDS NEBIS ETH-FOR',
#  'SzZuIDS NEBIS UNI-RWI',
#  'SzZuIDS NEBIS FHNW-PH-A',
#  'SzZuIDS BS/BE A310',
#  'SzZuIDS BS/BE A354',
#  'SzZuIDS BS/BE B498',
#  'EMPA-SG',
#  'HFHS',
#  'SzZuIDS FHB',
#  'HFHB',
#  'HPHS',
#  'HPHRM',
#  'RERO geulal',
#  'HPHRS',
#  'RERO vsbrod',
#  'SGBN SGKBV',
#  'SGBN SGARK',
#  'SGBN SGKSB',
#  'SGBN SGKSH',
#  'SGBN SGKSS',
#  'SzZuIDS NEBIS FH-FHA-PA',
#  'ETH-BAU',
#  'SGBN FLLB',
#  'UNI-RWS',
#  'SzZuIDS NEBIS SIKJM',
#  'FH-FHA-PA',
#  'SzZuIDS NEBIS FH-ZHW-T',
#  'SzBzSBTc LOBC',
#  'ETH-BWI',
#  'IDS BS/BE A110',
#  'RERO geueti',
#  'SzZuIDS LU LUMHS',
#  'SzZuIDS BS/BE B591',
#  'STS-TI',
#  'RERO gecaeg',
#  'IDS BS/BE A125',
#  'ISBE',
#  'SzZuIDS NEBIS ETH-NADEL',
#  'SzZuIDS BS/BE B565',
#  'SzZuIDS BS/BE A250',
#  'SGBN SGHSR',
#  'SLM',
#  'EPF-BC',
#  'SGBN SGKFA',
#  'SIK',
#  'SzZuIDS LU LUHTA',
#  'SO-HWV',
#  'SzZuIDS BS/BE B534',
#  'IDS NEBIS ETH-IPW',
#  'ISOE',
#  'ISC',
#  'SzZuIDS NEBIS PH-SO',
#  'PHS',
#  'SzZuIDS NEBIS FH-FHA-PB',
#  'RERO fru-le',
#  'IDS BS/BE B593',
#  'SzZuIDS BS/BE A252',
#  'RERO iftflu',
#  'ETH-FSK',
#  'SzZuIDS BS/BE A226',
#  'SGBN SGZFB',
#  'SzZuIDS BS/BE A332',
#  'SzZuIDS NEBIS UZH-HS',
#  '1248',
#  'SzZUIDS LU',
#  'SzZuIDS BS/BE B415',
#  'SzZuIDS NEBIS FHNW-PH-SP',
#  'DE-12',
#  'SzZuIDS NEBIS UZH-GEOG',
#  'SzZuIDS NEBIS ETH-GRUEN',
#  'SzZuIDS NEBIS ZHAW-HSB-WIN',
#  'SzZuIDS NEBIS ZHAW-P',
#  'SzZuIDS NEBIS FHNW-PH-B',
#  'SzZuIDS LU LUPHZ',
#  'SzBzSBTc MEOSC',
#  'SzBzSBTc BZSTA',
#  'SzBzSBTc BZAST',
#  'SzBzSBTc IUFFP',
#  'SzBzSBTc MEAA',
#  'SzBzSBTc',
#  'SzZuIDS NEBIS HES-EIVD',
#  'SzBzSBTc LUBC',
#  'TFL',
#  'SUPSI',
#  'SzZuIDS NEBIS SUPSI',
#  'SLB labcud',
#  'SzBzSBTc tibcma',
#  'SzBzSBTc tibrb-',
#  'RERO labdfm',
#  'RERO geuses',
#  'RERO laisdc',
#  'SzBzSBTs MALo',
#  'SzBzSBTc tibcme',
#  'RERO tibrb-',
#  'RERO tiire-',
#  'RERO tibcfg',
#  'SzBzSBTc MEBC',
#  'RERO tibrlm',
#  'RERO tibc--',
#  'RERO laidap',
#  'RERO tibcme',
#  'RERO geulha',
#  'RERO geubib',
#  'RERO larero',
#  'SzZuIDS BS/BE A242',
#  'RERO ticld-',
#  'IDS NEBIS FH-SO-HSW',
#  'WaSeSS',
#  'SzBzSBTc LOASP',
#  'RERO geuchr',
#  'SzBzSBTc ISPFP',
#  'RERO labcue',
#  'RERO geucui',
#  'SzBzSBTc tiire-',
#  'SzBzSBTc tibrlm',
#  'SzBzSBTs LIBe',
#  'IDS NEBIS ETH-BIB',
#  'RERO tibcma',
#  'RERO gepiag',
#  'RERO geheds',
#  'FRBNF',
#  'CDX',
#  'Q3A',
#  'AU@',
#  'CH-ZuSLS HESSO hegge',
#  'wbv Publikation',
#  'Brill | mentis',
#  'Brill | Fink',
#  'SzZuIDS UZB USIUZ',
#  'CH-ZuSLS UBS A301',
#  'CH-ZuSLS OSTGR E27',
#  'GEBAY',
#  'YUS',
#  'RNV vdmont',
#  'RNV vdvila',
#  'RNV vdvalb',
#  'CH-ZuSLS HESSO HEIG-VD',
#  'SzZuIDS NEBIS ZHAW-HSB-WAE',
#  'TVZ Theologischer Verlag Zürich',
#  'RNV vdappl',
#  'CH-ZuSLS RZH E45',
#  'CH-ZuSLS VGE',
#  'RERO frheps',
#  '1239',
#  'NUKAT',
#  'vdf Hochschulverlag',
#  'TEFOD',
#  'RNV vdoche',
#  'CH-ZuSLS UNINE',
#  'SzZuIDS BS/BE A302',
#  'RNV vdtour',
#  'AuAdUSA',
#  'CH-ZuSLS ISR fili',
#  'RNV vdpsvev',
#  'RERO vdcors',
#  'CH-ZuSLS HPH SUFFP',
#  'RNV 9782091247243',
#  'RERO geumem',
#  'RERO frvbef',
#  'Ernst Reinhardt Verlag',
#  'facultas',
#  'CH-ZuSLS HPH IFFP',
#  'RNV vdburi',
#  'CH-ZuSLS HESSO vshevs',
#  'SzZuIDS NEBIS FH-HTW-CHUR',
#  'RNV vdessc',
#  'C3L',
#  'SzZuIDS NEBIS HES-EHL',
#  'transcript Verlag',
#  'RERO vdmont',
#  'CH-ZuSLS UZB UHS',
#  'BEATB',
#  'RNV laels-',
#  'CH-ZuSLS FR',
#  'RERO laels-',
#  'SzZuIDS NEBIS HES-HEIG-VD',
#  'AUXAM',
#  'RERO vdecha',
#  'CH-ZuSLS HESSO EHL',
#  'UMA.HUM',
#  'RNV vdcite',
#  'RUQBL',
#  'UAB',
#  'SZ9XM',
#  'RNV vdprex',
#  'RNV vdlavi',
#  'CH-ZuSLS BFH E56',
#  'CH-ZuSLS USI',
#  'CH-ZuSLS HESSO vsests',
#  'CH-ZuSLS HPH HEFP',
#  'UkLUC',
#  'UK-SaU',
#  'CH-ZUSLS HPH HEFP',
#  'CH-ZuSLS UZB UEZEN',
#  'LI-VaLIL',
#  'RNV vdecub',
#  'CA7GT',
#  'CH-ZuSLS HPH PHRS',
#  'CaOWtL',
#  'CH-ZuSLS HPH PSG',
#  'CaToSAGE',
#  'CKB',
#  'CaBNVSL',
#  'QCHH',
#  'NhCcYBP',
#  'UkLoBP',
#  'UMA.RE',
#  'ICU/DLC',
#  'MH/DLC',
#  'CaONFJC',
#  'CH-ZuSLS UZB UKHIS',
#  'CaOLK',
#  'NO-OsNB',
#  'ES-BaUB',
#  'CaOONL',
#  'MsSM/DLC',
#  'DPL',
#  'DID',
#  'CaOWtU',
#  'BeLVLBS',
#  '(AR-BaUTT)',
#  'il4j6',
#  'FlBoTFG',
#  'JSTOR',
#  'PU/DLC',
#  'NCSU',
#  'Z5U',
#  'ger',
#  'UkBaUB',
#  'UVA',
#  'SUA',
#  'NDD',
#  'DNLM/DLC',
#  'P@U',
#  'AR-BaUTT',
#  'UIU',
#  'RECBK',
#  'FI-Tamy',
#  'DGITA',
#  'Evangelische Verlagsanstalt',
#  'RNV vdpull',
#  'RNV vdbstl vdorbe',
#  'SzZuIDS NEBIS ETH-HCI',
#  'RERO vdprev',
#  'SILIS',
#  '1230',
#  'RERO vsmome',
#  'CH-ZUSLS HPH IFFP',
#  'RERO gevcjb',
#  'RNVvdvall',
#  'CH-ZuSLS HESSO arcca1',
#  'CH-ZUSLS HPH PHSG',
#  'RNV vdgdsn',
#  'CH-ZuSLS HESSO frhess',
#  'RERO frhess',
#  'CH-ZuSLS BSB B425',
#  'CH-ZuSLS ZPH PHZH  $b ger',
#  'SzZuIDS NEBIS HES-HEIG-VD HESSO vsheso',
#  'SzZuIDS NEBIS FH-NTB',
#  'RERO geulph',
#  'SzZuIDS NEBIS UZH-BOT',
#  'RNV vdren',
#  'Q3C',
#  'RERO geheg-',
#  'GyGoGBV',
#  'CH-ZuSLS BCUFFR',
#  'RERO bemcip',
#  'ZD0',
#  'RNV vdmarens']

# %%
# On suppose qu'il y a "hep" ou "HEP" dans le champ 040
dg = d_2021.loc[d_2021['Original Cataloging Agency'].str.contains('hep')].copy()

# Erreur à cause des valeurs manquantes => utilisation de fillna
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_631/1213979996.py in <module>
#       1 # On suppose qu'il y a "hep" ou "HEP" dans le champ 040
# ----> 2 dg = d_2021.loc[d_2021['Original Cataloging Agency'].str.contains('hep')].copy()
#       3
#       4 # Erreur à cause des valeurs manquantes => utilisation de fillna
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1141             self._validate_key(key, axis)
#    1142             return self._get_slice_axis(key, axis=axis)
# -> 1143         elif com.is_bool_indexer(key):
#    1144             return self._getbool_axis(key, axis=axis)
#    1145         elif is_list_like_indexer(key):
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     137                     # Don't raise on e.g. ["A", "B", np.nan], see
#     138                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 139                     raise ValueError(na_msg)
#     140                 return False
#     141             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
# On remplace les valeurs manquantes par ""
d_2021['Original Cataloging Agency'] = d_2021['Original Cataloging Agency'].fillna('')

# La sélection va être possible
dg = d_2021.loc[d_2021['Original Cataloging Agency'].str.contains('hep')].copy()

# Autre possibilité sans changer les données:
# dg = d_2021.loc[d_2021['Original Cataloging Agency'].str.contains('hep').fillna(False)].copy()

# Il faut remplir par False dans ce contexe, en effet '.str.contains' retourne True/False/NaN
# => si NaN cela engendre une erreur

# Autre possibilité, supprimer les lignes où il y a des valeurs manquantes dans la colonne 'Original Cataloging Agency'
# dg = d_2021.dropna(subset=['Original Cataloging Agency'])

# %%
list(dg['Original Cataloging Agency'].unique())
# Out:
# ['RERO frvhep', 'RERO njhep-', 'RNV vdhep-', 'RERO frheps']

# %%
# Sélection des notices de la HEP-BEJUNE (on ignore la notice "jnhep-")
d_njhep = d_2021.loc[(d_2021['Original Cataloging Agency'].str.contains('njhep'))].copy()
d_njhep.head()
# Out:
#                     MMS Id Original Cataloging Agency  \
# 561148  991001405669205520                RERO njhep-
# 561291  991001406065105520                RERO njhep-
# 561292  991001406065205520                RERO njhep-
# 676910  991001445157005520                RERO njhep-
# 678070  991001447856905520                RERO njhep-
#
#        Creation Date (Calendar)  \
# 561148               2021-02-16
# 561291               2021-02-15
# 561292               2021-02-15
# 676910               2021-09-13
# 678070               2021-10-06
#
#                                                  Title
# 561148          Télescope : Orion : StarSeeker IV GoTo
# 561291  Télescope : Orion : StarSeeker IV GoTo TEST FB
# 561292                     iPad : Apple : iPad test FB
# 676910        Prendre en compte la diversité à l'école
# 678070       Bioviva junior le jeu naturellement drôle

# %%
nb_hep_bejune = len(d_njhep)
nb_not_hep_bejune = len(d_2021) - nb_hep_bejune
print(f'Nombre de notices HEP-BEJUNE: {nb_hep_bejune} / {len(d_2021)}')
print(f'Nombre de notices hors HEP-BEJUNE: {nb_not_hep_bejune} / {len(d_2021)}')
# Out:
# Nombre de notices HEP-BEJUNE: 7 / 143387
# Nombre de notices hors HEP-BEJUNE: 143380 / 143387

# %% [markdown]
# **Explication du résultat:**
# Il y a 7 notices en 2021 qui ont reçu le tag "njhep" dans le champ 040. Il y a eu 143'387 nouvelles notices dans l'IZ HPH. Cela ne signifie pas du tout que la médiathèque HEP-BEJUNE possède des exemplaires associés. On ne peut donc pas déterminer sur ces données une proportion de catalogage natif pour cette bibliothèque par rapport à ses acquisitions.
