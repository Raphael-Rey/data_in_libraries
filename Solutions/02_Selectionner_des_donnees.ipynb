# %% [markdown]
# ## Exercice 2
# ## Sélectionner des données
# Une opération très courante est de sélectionner un ensemble particulier de données sur la base de critères.
#
# ### Consigne
# Le fichier `Data/items_reduced.csv` contient les exemplaires de la Médiathèque de Bienne (Sandbox Alma SLSP).
#
# Créer un fichier `Resultat/items_loanable.csv` qui ne contient que les exemplaires empruntables.
#
# **Exercie plus avancé:**
# * Trouver les titres à la fois en localisation 'BE HEP Littérature jeunesse' et en localisation 'BE HEP Séries de livres'
# * Trouver les titres qui sont présent dans 'BE HEP Séries de livres' mais pas dans 'BE HEP Littérature jeunesse'
# * Choisir 20 exemplaires au hasard

# %%
# Importer les bibliothèques requises
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Chargement des données
df = pd.read_csv('Data/items_reduced.csv')

# %%
df.columns
# Out:
# Index(['Barcode', 'MMS ID', 'Holdings ID', 'Permanent Location', 'Call Number',
#        'Material Type', 'Item Policy', 'Title'],
#       dtype='object')

# %%
df['Item Policy'].unique()
# Out:
# array(['97 Booking / Loan max. 14 days, campus, no copy',
#        '54 Booking 56 days / No loan request, loan 28 days, no copy',
#        '01 Loan 28 days', '04 Loan 28 days, no copy', nan,
#        '67 No use, no copy', '68 On-site use only, no copy',
#        '70 Use on request, contact the library', 'EMPTY',
#        '06 Loan max. 28 days, no courier/delivery',
#        '81 Booking / Loan 28 days, campus'], dtype=object)

# %%
loanable_item_policies = ['01 Loan 28 days', '04 Loan 28 days, no copy', '81 Booking / Loan 28 days, campus']

# Sélection sur la base d'une liste de valeur
dg = df.loc[df['Item Policy'].isin(loanable_item_policies)].copy()
dg.head()
# Out:
#     Barcode              MMS ID        Holdings ID  \
# 4  03138420  991001610643905520  22106459710005520
# 5  03140943  991001604441405520  22106459620005520
# 6  03140944  991001604441405520  22106459620005520
# 7  03137107  991001610343705520  22106419560005520
# 8  03138415  991001609741405520  22106353530005520
#
#             Permanent Location      Call Number Material Type  \
# 4  BE HEP Littérature jeunesse       HEPBE COLO          Book
# 5                  BE HEP Jeux  HEPBE MATH TURI          Game
# 6                  BE HEP Jeux  HEPBE MATH TURI          Game
# 7    BE HEP Fonds documentaire  HEPBE 745.5HAYE          Book
# 8  BE HEP Littérature jeunesse    HEPBE BD MAUR          Book
#
#                 Item Policy                                              Title
# 4           01 Loan 28 days  Les pêcheurs d'éternité Marie Colot ; illustra...
# 5  04 Loan 28 days, no copy  Turing tumble construis un ordinateur à billes...
# 6  04 Loan 28 days, no copy  Turing tumble construis un ordinateur à billes...
# 7           01 Loan 28 days            40 créations avec la nature Fiona Hayes
# 8           01 Loan 28 days  Eden scénario : Fabrice Colin ; dessin et coul...

# %%
print('df shape: ', df.shape)
print('dg shape: ', dg.shape)
# Out:
# df shape:  (34686, 8)
# dg shape:  (24801, 8)

# %%
dg['Item Policy'].value_counts()
# Out:
# 01 Loan 28 days                      22038
# 04 Loan 28 days, no copy              2762
# 81 Booking / Loan 28 days, campus        1
# Name: Item Policy, dtype: int64

# %%
dg.to_excel('Resultat/loanable_items.xlsx', index=False)

# %% [markdown]
# ### Exercices avancés

# %%
# Créer une table pour l'emplacement 'BE HEP Séries de livres' uniquement
d_series = df.loc[df['Permanent Location']=='BE HEP Séries de livres'].copy()
d_series.head()
# Out:
#      Barcode              MMS ID        Holdings ID       Permanent Location  \
# 3   03138226  991000065799705520  22106499280005520  BE HEP Séries de livres
# 13  03138221  991000457309705520  22106164210005520  BE HEP Séries de livres
# 14  03138222  991000342239705520  22106074260005520  BE HEP Séries de livres
# 15  03138224  991000495599705520  22106192790005520  BE HEP Séries de livres
# 16  03138225  991000080099705520  22106212180005520  BE HEP Séries de livres
#
#       Call Number Material Type  \
# 3    HEPBE 6 VEND          Book
# 13   HEPBE 8 FARR          Book
# 14   HEPBE 8 GRAN          Book
# 15   HEPBE 6 GUTM          Book
# 16  HEPBE 10 MOUC          Book
#
#                                           Item Policy  \
# 3   54 Booking 56 days / No loan request, loan 28 ...
# 13  54 Booking 56 days / No loan request, loan 28 ...
# 14  54 Booking 56 days / No loan request, loan 28 ...
# 15  54 Booking 56 days / No loan request, loan 28 ...
# 16  54 Booking 56 days / No loan request, loan 28 ...
#
#                                                 Title
# 3   La disparition de Sam Edward van de Vendel ; t...
# 13  L'aventure de Castle Rock Natasha Farrant ; tr...
# 14  Famille à louer Vicki Grant ; traduit de l'ang...
# 15                      Les inséparables Colas Gutman
# 16              Alex fils d'esclave Christel Mouchard

# %%
# Créer une table pour l'emplacement 'BE HEP Littérature jeunesse' uniquement
d_lit = df.loc[df['Permanent Location']=='BE HEP Littérature jeunesse'].copy()
d_series.head()
# Out:
#      Barcode              MMS ID        Holdings ID       Permanent Location  \
# 3   03138226  991000065799705520  22106499280005520  BE HEP Séries de livres
# 13  03138221  991000457309705520  22106164210005520  BE HEP Séries de livres
# 14  03138222  991000342239705520  22106074260005520  BE HEP Séries de livres
# 15  03138224  991000495599705520  22106192790005520  BE HEP Séries de livres
# 16  03138225  991000080099705520  22106212180005520  BE HEP Séries de livres
#
#       Call Number Material Type  \
# 3    HEPBE 6 VEND          Book
# 13   HEPBE 8 FARR          Book
# 14   HEPBE 8 GRAN          Book
# 15   HEPBE 6 GUTM          Book
# 16  HEPBE 10 MOUC          Book
#
#                                           Item Policy  \
# 3   54 Booking 56 days / No loan request, loan 28 ...
# 13  54 Booking 56 days / No loan request, loan 28 ...
# 14  54 Booking 56 days / No loan request, loan 28 ...
# 15  54 Booking 56 days / No loan request, loan 28 ...
# 16  54 Booking 56 days / No loan request, loan 28 ...
#
#                                                 Title
# 3   La disparition de Sam Edward van de Vendel ; t...
# 13  L'aventure de Castle Rock Natasha Farrant ; tr...
# 14  Famille à louer Vicki Grant ; traduit de l'ang...
# 15                      Les inséparables Colas Gutman
# 16              Alex fils d'esclave Christel Mouchard

# %%
# Trouver les exemplaires présents dans les séries et dans l'emplacement littérature jeunesse
d_lit[d_lit['MMS ID'].isin(d_series['MMS ID'])]
# Out:
#         Barcode              MMS ID       Holdings ID  \
# 2316   03100071  991000556049705520  2237697910005520
# 6891   03131653  991001167009705520  2236990660005520
# 8556   03136483  991000545299705520  2236740450005520
# 8833   03137104  991001114759705520  2236698800005520
# 10916  03125284  991000786039705520  2236355300005520
# 15620  03136759  991000052099705520  2235659440005520
# 19581  03114929  991000335759705520  2235061010005520
# 20528  03137379  991000559839705520  2234892270005520
# 20548  03118254  991000119309705520  2234887850005520
# 21729  03137593  991000205349705520  2234688740005520
# 22048  03114894  991000268229705520  2234636250005520
# 26785  03137112  991000619939705520  2233938430005520
# 29315  03139179  991000108079705520  2233536860005520
# 29716  03136488  991000822789705520  2233471850005520
# 29761  03111136  991000300339705520  2233463400005520
# 30912  03127446  991000468339705520  2233295940005520
# 32243  03125994  991000181189705520  2233088160005520
# 32904  03131311  991000824229705520  2232980740005520
#
#                 Permanent Location    Call Number Material Type  \
# 2316   BE HEP Littérature jeunesse     HEPBE DAHL          Book
# 6891   BE HEP Littérature jeunesse  HEPBE BD SORE          Book
# 8556   BE HEP Littérature jeunesse     HEPBE GUIL          Book
# 8833   BE HEP Littérature jeunesse     HEPBE AUBR          Book
# 10916  BE HEP Littérature jeunesse     HEPBE RUAT          Book
# 15620  BE HEP Littérature jeunesse     HEPBE MORG          Book
# 19581  BE HEP Littérature jeunesse     HEPBE FERD          Book
# 20528  BE HEP Littérature jeunesse     HEPBE ROSE          Book
# 20548  BE HEP Littérature jeunesse     HEPBE BOYN          Book
# 21729  BE HEP Littérature jeunesse     HEPBE MEUN          Book
# 22048  BE HEP Littérature jeunesse     HEPBE BOTT          Book
# 26785  BE HEP Littérature jeunesse     HEPBE PETI          Book
# 29315  BE HEP Littérature jeunesse     HEPBE BARO          Book
# 29716  BE HEP Littérature jeunesse     HEPBE REBE          Book
# 29761  BE HEP Littérature jeunesse     HEPBE FRIO          Book
# 30912  BE HEP Littérature jeunesse          HEPBE          Book
# 32243  BE HEP Littérature jeunesse     HEPBE MURA          Book
# 32904  BE HEP Littérature jeunesse     HEPBE DOIN          Book
#
#            Item Policy                                              Title
# 2316   01 Loan 28 days  Charlie et la chocolaterie Roald Dahl ; trad. ...
# 6891   01 Loan 28 days  Le Horla Guillaume Sorel ; d'après l'oeuvre de...
# 8556   01 Loan 28 days  Mémed et les 40 menteurs Françoise Guillaumond...
# 8833   01 Loan 28 days                          Titan noir Florence Aubry
# 10916  01 Loan 28 days  La petite fille dans une boîte en verre Marie ...
# 15620  01 Loan 28 days  Les fées du camping Susie Morgenstern ; ill. d...
# 19581  01 Loan 28 days                       Minuit-Cinq Malika Ferdjoukh
# 20528  01 Loan 28 days  Les chats de la tour Eiffel Auro Roselli ; tra...
# 20548  01 Loan 28 days  Le garçon en pyjama rayé une fable de Jon Boyn...
# 21729  01 Loan 28 days  Taupe & mulot les beaux jours Henri Meunier & ...
# 22048  01 Loan 28 days  Princesse en danger Pierre Bottero, Marie-Pier...
# 26785  01 Loan 28 days                      Le mot d'Abel Véronique Petit
# 29315  01 Loan 28 days  Dans les dents ! une vie d'ogre Denis Baronnet...
# 29716  01 Loan 28 days        Même pas peur! Evelyne Reberg, Nancy Ribard
# 29761  01 Loan 28 days                   Histoires pressées Bernard Friot
# 30912  01 Loan 28 days   Ferdinand et ses micropouvoirs Hélèna Villovitch
# 32243  01 Loan 28 days             Scénario catastrophe Marie-Aude Murail
# 32904  01 Loan 28 days  Un piano pour Pavel Mymi Doinet ; illustration...

# %%
# Trouver les exemplaires présents dans les séries mais pas dans l'emplacement littérature jeunesse
d_series[~d_series['MMS ID'].isin(d_lit['MMS ID'])]
# Out:
#         Barcode              MMS ID        Holdings ID  \
# 3      03138226  991000065799705520  22106499280005520
# 13     03138221  991000457309705520  22106164210005520
# 14     03138222  991000342239705520  22106074260005520
# 15     03138224  991000495599705520  22106192790005520
# 16     03138225  991000080099705520  22106212180005520
# ...         ...                 ...                ...
# 34562  03120338  991000518369705520   2232738190005520
# 34599  03115733  991000783119705520   2232730800005520
# 34669  03115905  991000731059705520   2232714960005520
# 34671  03115505  991000138089705520   2232714070005520
# 34675  03138628  991001140809705520   2232713060005520
#
#             Permanent Location    Call Number Material Type  \
# 3      BE HEP Séries de livres   HEPBE 6 VEND          Book
# 13     BE HEP Séries de livres   HEPBE 8 FARR          Book
# 14     BE HEP Séries de livres   HEPBE 8 GRAN          Book
# 15     BE HEP Séries de livres   HEPBE 6 GUTM          Book
# 16     BE HEP Séries de livres  HEPBE 10 MOUC          Book
# ...                        ...            ...           ...
# 34562  BE HEP Séries de livres   HEPBE 6 CHER          Book
# 34599  BE HEP Séries de livres  HEPBE 11 SACH          Book
# 34669  BE HEP Séries de livres   HEPBE 4 ESCO          Book
# 34671  BE HEP Séries de livres   HEPBE 4 VOLT          Book
# 34675  BE HEP Séries de livres   HEPBE 6 VANT          Book
#
#                                              Item Policy  \
# 3      54 Booking 56 days / No loan request, loan 28 ...
# 13     54 Booking 56 days / No loan request, loan 28 ...
# 14     54 Booking 56 days / No loan request, loan 28 ...
# 15     54 Booking 56 days / No loan request, loan 28 ...
# 16     54 Booking 56 days / No loan request, loan 28 ...
# ...                                                  ...
# 34562  54 Booking 56 days / No loan request, loan 28 ...
# 34599  54 Booking 56 days / No loan request, loan 28 ...
# 34669  54 Booking 56 days / No loan request, loan 28 ...
# 34671  54 Booking 56 days / No loan request, loan 28 ...
# 34675  54 Booking 56 days / No loan request, loan 28 ...
#
#                                                    Title
# 3      La disparition de Sam Edward van de Vendel ; t...
# 13     L'aventure de Castle Rock Natasha Farrant ; tr...
# 14     Famille à louer Vicki Grant ; traduit de l'ang...
# 15                         Les inséparables Colas Gutman
# 16                 Alex fils d'esclave Christel Mouchard
# ...                                                  ...
# 34562  La santé sans télé Sophie Chérer ; ill. de Vér...
# 34599  Le passage Louis Sachar ; trad. de l'américain...
# 34669  Le noeud de la girafe Michaël Escoffier ; ill....
# 34671  Le livre le plus génial que j'ai jamais lu.. C...
# 34675                         Sauf que roman Anne Vantal
#
# [1039 rows x 8 columns]

# %%
d_series
# Out:
#         Barcode              MMS ID        Holdings ID  \
# 3      03138226  991000065799705520  22106499280005520
# 13     03138221  991000457309705520  22106164210005520
# 14     03138222  991000342239705520  22106074260005520
# 15     03138224  991000495599705520  22106192790005520
# 16     03138225  991000080099705520  22106212180005520
# ...         ...                 ...                ...
# 34562  03120338  991000518369705520   2232738190005520
# 34599  03115733  991000783119705520   2232730800005520
# 34669  03115905  991000731059705520   2232714960005520
# 34671  03115505  991000138089705520   2232714070005520
# 34675  03138628  991001140809705520   2232713060005520
#
#             Permanent Location    Call Number Material Type  \
# 3      BE HEP Séries de livres   HEPBE 6 VEND          Book
# 13     BE HEP Séries de livres   HEPBE 8 FARR          Book
# 14     BE HEP Séries de livres   HEPBE 8 GRAN          Book
# 15     BE HEP Séries de livres   HEPBE 6 GUTM          Book
# 16     BE HEP Séries de livres  HEPBE 10 MOUC          Book
# ...                        ...            ...           ...
# 34562  BE HEP Séries de livres   HEPBE 6 CHER          Book
# 34599  BE HEP Séries de livres  HEPBE 11 SACH          Book
# 34669  BE HEP Séries de livres   HEPBE 4 ESCO          Book
# 34671  BE HEP Séries de livres   HEPBE 4 VOLT          Book
# 34675  BE HEP Séries de livres   HEPBE 6 VANT          Book
#
#                                              Item Policy  \
# 3      54 Booking 56 days / No loan request, loan 28 ...
# 13     54 Booking 56 days / No loan request, loan 28 ...
# 14     54 Booking 56 days / No loan request, loan 28 ...
# 15     54 Booking 56 days / No loan request, loan 28 ...
# 16     54 Booking 56 days / No loan request, loan 28 ...
# ...                                                  ...
# 34562  54 Booking 56 days / No loan request, loan 28 ...
# 34599  54 Booking 56 days / No loan request, loan 28 ...
# 34669  54 Booking 56 days / No loan request, loan 28 ...
# 34671  54 Booking 56 days / No loan request, loan 28 ...
# 34675  54 Booking 56 days / No loan request, loan 28 ...
#
#                                                    Title
# 3      La disparition de Sam Edward van de Vendel ; t...
# 13     L'aventure de Castle Rock Natasha Farrant ; tr...
# 14     Famille à louer Vicki Grant ; traduit de l'ang...
# 15                         Les inséparables Colas Gutman
# 16                 Alex fils d'esclave Christel Mouchard
# ...                                                  ...
# 34562  La santé sans télé Sophie Chérer ; ill. de Vér...
# 34599  Le passage Louis Sachar ; trad. de l'américain...
# 34669  Le noeud de la girafe Michaël Escoffier ; ill....
# 34671  Le livre le plus génial que j'ai jamais lu.. C...
# 34675                         Sauf que roman Anne Vantal
#
# [1057 rows x 8 columns]

# %%
# 20 exemplaires au hasard
df.sample(20)
# Out:
#              Barcode              MMS ID       Holdings ID  \
# 34539       03136396  991001208469705520  2232741840005520
# 18899       HEP72313  991000293679705520  2235146680005520
# 18839       03133650  991001170839705520  2235157290005520
# 13022  RERO-18961910  991000500249705520  2236008820005520
# 1021        03137521  991001187859705520  2250194440005520
# 29154       03111818  991000118819705520  2233563800005520
# 19989       03114854  991000152429705520  2234981650005520
# 27230       03113422  991000425609705520  2233853230005520
# 26985       03102189  991001153689705520  2233901100005520
# 964      HPH-S-13176  991000353899705520  2237576490005520
# 24091       03117426  991000799779705520  2234331610005520
# 14789       03132184  991000258449705520  2235786970005520
# 24796       03100584  991000055809705520  2234219960005520
# 13486       03119821  991000740829705520  2235959310005520
# 9824        03108944  991000565049705520  2236535450005520
# 5497        03107198  991000642889705520  2237201820005520
# 11871       HEP72570  991001061589705520  2236215450005520
# 19876       03136039  991000769679705520  2235005780005520
# 21921       03129964  991000578799705520  2234653170005520
# 19119       03101442  991000117029705520  2235121860005520
#
#                 Permanent Location               Call Number Material Type  \
# 34539    BE HEP Fonds documentaire         HEPBE 159.953LIEU          Book
# 18899        BE JU NE HEP Articles                         -          Book
# 18839                  BE HEP Jeux           HEPBE ENVI SCHU          Game
# 13022        BE JU NE HEP Articles                         -          Book
# 1021                 BE HEP Albums                HEPBE GUIL          Book
# 29154    BE HEP Fonds documentaire             HEPBE 165MOND          Book
# 19989      BE HEP Séries de livres              HEPBE 4 REYN          Book
# 27230    BE HEP Fonds documentaire          HEPBE 372.41DEMO          Book
# 26985    BE HEP Fonds documentaire         HEPBE 37(092)PEST          Book
# 964             BE HEP Périodiques  HEPBE GAZETTE DU TET-ART         Issue
# 24091    BE HEP Fonds documentaire              HEPBE 52REEV          Book
# 14789  BE HEP Littérature jeunesse    HEPBE PREM LECT RICH/2          Book
# 24796    BE HEP Fonds documentaire           HEPBE 373.2ECOL          Book
# 13486           BE HEP Périodiques           HEPBE EDUCATEUR         Issue
# 9824     BE HEP Fonds documentaire           HEPBE 591.9HAVA          Book
# 5497     BE HEP Fonds documentaire        HEPBE 784.67GROS/3           Kit
# 11871        BE JU NE HEP Articles                         -          Book
# 19876    BE HEP Fonds documentaire             HEPBE 501SCIE          Book
# 21921    BE HEP Fonds documentaire       HEPBE 159.923.2DUTO          Book
# 19119    BE HEP Fonds documentaire               HEPBE 5TEST          Book
#
#                                              Item Policy  \
# 34539                                    01 Loan 28 days
# 18899             70 Use on request, contact the library
# 18839                           04 Loan 28 days, no copy
# 13022             70 Use on request, contact the library
# 1021                                     01 Loan 28 days
# 29154                                    01 Loan 28 days
# 19989  54 Booking 56 days / No loan request, loan 28 ...
# 27230                                    01 Loan 28 days
# 26985                                    01 Loan 28 days
# 964                                                  NaN
# 24091                                    01 Loan 28 days
# 14789                                    01 Loan 28 days
# 24796                                    01 Loan 28 days
# 13486                                    01 Loan 28 days
# 9824                                     01 Loan 28 days
# 5497                                     01 Loan 28 days
# 11871             70 Use on request, contact the library
# 19876                                    01 Loan 28 days
# 21921                                    01 Loan 28 days
# 19119                                    01 Loan 28 days
#
#                                                    Title
# 34539                Le livre de la mémoire Alain Lieury
# 18899                                    Jeux de pouvoir
# 18839  Rund ums Jahr = Histoires des saisons ... Simo...
# 13022  Thématique corps enseignant et corps apprenant...
# 1021                        Pleine mer Antoine Guilloppé
# 29154  Chercheurs en interaction comment émergent les...
# 19989  Un bon point pour Zoé Peter H. Reynolds ; trad...
# 27230  Lire la littérature lire l'image, lire le text...
# 26985  Qui êtes-vous, monsieur Pestalozzi? Jacqueline...
# 964    La gazette du Têt-Art une revue dédiée aux enf...
# 24091  Patience dans l'azur l'évolution cosmique Hube...
# 14789  Qui vit dans ma maison ? Béatrice M. Richet et...
# 24796  L'école avant six ans guide du maître François...
# 13486         Educateur Syndicat des enseignants romands
# 9824   Animaux des champs Christian Havard, Catherine...
# 5497   Les animaux 3 Les petits animaux des bois et d...
# 11871  La Chine au temps des fumeries d'opium par Xav...
# 19876  Sciences expérimentales et technologie CM2 Jea...
# 21921  Etre vu, se voir, se donner à voir Martine Dut...
# 19119  Nature en jeux méthodologie, activités, connai...
